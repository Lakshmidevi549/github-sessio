# %% [markdown]
# # how to create a null values

# %% [markdown]
# - None
# - np.num

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # none

# %%
d={'Names':['Ramesh','Suresh',None,'Mahesh'],
   'Age':[None,22,23,25],
   'City':['Hyd','Blr','Pune',None]}
df1=pd.DataFrame(d)
df1
# Out:
#     Names   Age  City
# 0  Ramesh   NaN   Hyd
# 1  Suresh  22.0   Blr
# 2     NaN  23.0  Pune
# 3  Mahesh  25.0   NaN

# %%
df1.to_csv('data1.csv',index=False)

# %% [markdown]
# # np.nan

# %%
d={'Names':['Ramesh','Suresh',np.nan,'Mahesh'],
   'Age':[np.nan,22,24,25],
  'City':['Hyd','Blr','Pune',np.nan]}
df2=pd.DataFrame(d)
df2
# Out:
#     Names   Age  City
# 0  Ramesh   NaN   Hyd
# 1  Suresh  22.0   Blr
# 2     NaN  24.0  Pune
# 3  Mahesh  25.0   NaN

# %%
df2.to_csv('data2.csv',index=False)

# %% [markdown]
# - categorical data use **None**
# - numerical data use **np.nan**

# %%
#for example Numerical data
np.nan+10
# Out:
# nan

# %%
None+10
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 None+10
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'int'

# %%
df1.isnull()
# isnull= wherever Null value there it display as True
# Out:
#    Names    Age   City
# 0  False   True  False
# 1  False  False  False
# 2   True  False  False
# 3  False  False   True

# %%
df1.isnull().sum()
#counting the num of null values is there in columns
# Out:
# Names    1
# Age      1
# City     1
# dtype: int64

# %%
df1
df1.values
# Out:
# array([['Ramesh', nan, 'Hyd'],
#        ['Suresh', 22.0, 'Blr'],
#        [nan, 23.0, 'Pune'],
#        ['Mahesh', 25.0, nan]], dtype=object)

# %%
df1.dtypes
# Out:
# Names        str
# Age      float64
# City         str
# dtype: object

# %%
df1.isnull()
# Out:
#    Names    Age   City
# 0  False   True  False
# 1  False  False  False
# 2   True  False  False
# 3  False  False   True

# %% [markdown]
# # fill the values

# %%
# random fill
df1.fillna(30)
# Out:
#     Names   Age  City
# 0  Ramesh  30.0   Hyd
# 1  Suresh  22.0   Blr
# 2      30  23.0  Pune
# 3  Mahesh  25.0    30

# %%
#select one column and will with  values
df1['City'].fillna('Delhi')
# Out:
# 0      Hyd
# 1      Blr
# 2     Pune
# 3    Delhi
# Name: City, dtype: str

# %%
#
df1.fillna(30)
df1['City'].fillna('Delhi')
# Out:
# 0      Hyd
# 1      Blr
# 2     Pune
# 3    Delhi
# Name: City, dtype: str

# %%
df1
# Out:
#     Names   Age  City
# 0  Ramesh   NaN   Hyd
# 1  Suresh  22.0   Blr
# 2     NaN  23.0  Pune
# 3  Mahesh  25.0   NaN

# %%
#pad,ffill,bfill,backfill
#axis=0 axis=1
df1.ffill()
# Out:
#     Names   Age  City
# 0  Ramesh   NaN   Hyd
# 1  Suresh  22.0   Blr
# 2  Suresh  23.0  Pune
# 3  Mahesh  25.0  Pune

# %%
df1.bfill()
# Out:
#     Names   Age  City
# 0  Ramesh  22.0   Hyd
# 1  Suresh  22.0   Blr
# 2  Mahesh  23.0  Pune
# 3  Mahesh  25.0   NaN

# %%
df1.backfill()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20100\1128174623.py in ?()
# ----> 1 df1.backfill()
#
# ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\generic.py in ?(self, name)
#    6202             and name not in self._accessors
#    6203             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204         ):
#    6205             return self[name]
# -> 6206         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'backfill'

# %% [markdown]
# # mean,mediam,mode

# %% [markdown]
# - mean
#
# - median
#
# - mode

# %%
age_mean=df1['Age'].mean()
df1['Age'],fillna(age_mean)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 age_mean=df1['Age'].mean()
# ----> 2 df1['Age'],fillna(age_mean)
#
# NameError: name 'fillna' is not defined

# %%
# there ia no particular Rule  how to fill the missing values
# it is completely  based on situation

# %%
Gender={'Male','Female',None}
d1=pd.DataFrame(Gender,columns=['Gender'])
d1
# Out:
#    Gender
# 0     NaN
# 1    Male
# 2  Female

# %%
d={'Female':0,'Male':1}
d1

# %%
#the student think  that i want  to fill a missing
#data is numerical:meam
(1+0)/2
# Out:
# 0.5

# %%
Gender={'Male','Female',None}
d1=pd.DataFrame(Gender,columns=['Gender'])
d={'Female':0,'Male':1}

# %% [markdown]
# # situation-2

# %%
# Ml algorithm
# churn: stay or not stay
churn=['stay','not_stay',None]
churn=[0,1,None]
churn=[0,1,0.5]

# %% [markdown]
# # situation-3

# %%
# no of days
[20,25,np.nan,31]
(20+25+31)/3
# Out:
# 25.333333333333332

# %% [markdown]
# # situation-4

# %%
course=['Ds','Ai','Ds','devops','Ai']
fee=[30000,2700,3000,22000,3000]
pd.DataFrame(zip(course,fee),columns=['course','Fees'])
# Out:
#    course   Fees
# 0      Ds  30000
# 1      Ai   2700
# 2      Ds   3000
# 3  devops  22000
# 4      Ai   3000

# %% [markdown]
# # KKN (k- nearest neighbours)

# %% [markdown]
# - KNN: K-Nearest neighbours
# - where K is Number
# - instead of taking avg of all the values data
#      - first we will find the neighbours who are close with missing data
#      - by using Euclidian distance calculation will identify the neighbour rows first
#      - suppose k=2 will identify the 2 closest point first
#      - those closest rows values will take it, will calculate the mean
#      - Finally will fill with the mean

# %%
salary=[50000,np.nan,70000,90000]
age=[25,28,30,40]
df=pd.DataFrame(zip(salary,age),
                columns=['Salary','age'])
df
# Out:
#     Salary  age
# 0  50000.0   25
# 1      NaN   28
# 2  70000.0   30
# 3  90000.0   40

# %% [markdown]
# - sklearn
#     - impute
#         - KKNImputer

# %%
from sklearn.impute import KNNImputer

imputer = KNNImputer(n_neighbors=2)

df_new = pd.DataFrame(imputer.fit_transform(df), columns=df.columns)

df_new
# Out:
#     Salary   age
# 0  50000.0  25.0
# 1  60000.0  28.0
# 2  70000.0  30.0
# 3  90000.0  40.0
