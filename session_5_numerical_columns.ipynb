# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#read the data
visa_df=pd.read_csv("Visadataset.csv")
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
cat=visa_df.select_dtypes(include='str').columns.tolist()
num=visa_df.select_dtypes(exclude='str').columns.tolist()
cat,num
# Out:
# (['case_id',
#   'continent',
#   'education_of_employee',
#   'has_job_experience',
#   'requires_job_training',
#   'region_of_employment',
#   'unit_of_wage',
#   'full_time_position',
#   'case_status'],
#  ['no_of_employees', 'yr_of_estab', 'prevailing_wage'])

# %% [markdown]
# **prevailing_wage**

# %%
visa_df['prevailing_wage']
# Out:
# 0           592.2029
# 1         83425.6500
# 2        122996.8600
# 3         83434.0300
# 4        149907.3900
#             ...
# 25475     77092.5700
# 25476    279174.7900
# 25477    146298.8500
# 25478     86154.7700
# 25479     70876.9100
# Name: prevailing_wage, Length: 25480, dtype: float64

# %%
visa_df['prevailing_wage'].count()
# Out:
# np.int64(25480)

# %%
visa_df['prevailing_wage'].min()
# Out:
# 2.1367

# %%
visa_df['prevailing_wage'].max()
# Out:
# 319210.27

# %%
visa_df['prevailing_wage'].mean()
# Out:
# np.float64(74455.81459209183)

# %%
visa_df['prevailing_wage'].median()
# Out:
# 70308.20999999999

# %%
visa_df['prevailing_wage'].quantile(0.25)
# Out:
# np.float64(34015.479999999996)

# %%
visa_df['prevailing_wage'].quantile(0.50)
# Out:
# np.float64(70308.20999999999)

# %%
visa_df['prevailing_wage'].quantile(0.75)
# Out:
# np.float64(107735.51250000001)

# %%
pwage=visa_df['prevailing_wage']

# %%
Count=visa_df['prevailing_wage'].count(),
Min=visa_df['prevailing_wage'].min(),
P_25=round(np.percentile(visa_df['prevailing_wage'],25),2),
Mean=round(visa_df['prevailing_wage'].mean()),
Median=round(visa_df['prevailing_wage'].median()),
P_50=round(np.percentile(visa_df['prevailing_wage'],50),2),

P_75=round(np.percentile(visa_df['prevailing_wage'],75),2),
Max=round(visa_df['prevailing_wage'].max()),
l=[Count,Min,P_25,Mean,Median,P_50,P_75,Max]
ID=['Count','Min','25P','Mean','Median','50P','75p','Max']
pd.DataFrame(l,columns=['prevailing_wage'],
                        index=ID)
# Out:
#         prevailing_wage
# Count        25480.0000
# Min              2.1367
# 25P          34015.4800
# Mean         74456.0000
# Median       70308.0000
# 50P          70308.2100
# 75p         107735.5100
# Max         319210.0000

# %%
num=visa_df.select_dtypes(exclude='str').columns.tolist()
final_list=[]
for i in num:

    Count=visa_df[i].count(),
    Min=visa_df[i].min(),
    P_25=round(np.percentile(visa_df[i],25),2),
    Mean=round(visa_df[i].mean()),
    Median=round(visa_df[i].median()),
    P_50=round(np.percentile(visa_df[i],50),2),
    P_75=round(np.percentile(visa_df[i],75),2),
    Max=round(visa_df[i].max()),
    l=[Count,Min,P_25,Mean,Median,P_50,P_75,Max]
    final_list.append(l)
df=pd.DataFrame()
for i in final_list:
    df[f'{i}']=i
df.columns=num
df.index=ID
df
# Out:
#        no_of_employees yr_of_estab prevailing_wage
# Count         (25480,)    (25480,)        (25480,)
# Min             (-26,)     (1800,)       (2.1367,)
# 25P          (1022.0,)   (1976.0,)     (34015.48,)
# Mean           (5667,)     (1979,)        (74456,)
# Median         (2109,)     (1997,)        (70308,)
# 50P          (2109.0,)   (1997.0,)     (70308.21,)
# 75p          (3504.0,)   (2005.0,)    (107735.51,)
# Max          (602069,)     (2016,)       (319210,)

# %% [markdown]
# **Describe function**

# %%
visa_df.describe()
# Out:
#        no_of_employees   yr_of_estab  prevailing_wage
# count     25480.000000  25480.000000     25480.000000
# mean       5667.043210   1979.409929     74455.814592
# std       22877.928848     42.366929     52815.942327
# min         -26.000000   1800.000000         2.136700
# 25%        1022.000000   1976.000000     34015.480000
# 50%        2109.000000   1997.000000     70308.210000
# 75%        3504.000000   2005.000000    107735.512500
# max      602069.000000   2016.000000    319210.270000

# %% [markdown]
# **percentile**

# %%
wage_data=visa_df['prevailing_wage']
np.percentile(wage_data,25)
# Out:
# np.float64(34015.479999999996)

# %% [markdown]
# - 25 percentage of number of applicants have the wages lower than **34015.479999999996**
# - 25%(25480) has salary less than 34015.479999999996
# - 6370 applicants has salary less than 34015.479999999996

# %%
wage_data=visa_df['prevailing_wage']
con=wage_data<np.percentile(wage_data,25)
np.sum(con) #count the numbers
# Out:
# np.int64(6370)

# %%
visa_df[con] #extract the data
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 0         EZYV01           Asia           High School                  N
# 7         EZYV08  North America            Bachelor's                  Y
# 12        EZYV13           Asia            Bachelor's                  Y
# 16        EZYV17         Europe              Master's                  Y
# 17        EZYV18           Asia              Master's                  Y
# ...          ...            ...                   ...                ...
# 25461  EZYV25462           Asia              Master's                  Y
# 25465  EZYV25466  North America           High School                  N
# 25466  EZYV25467         Europe            Bachelor's                  Y
# 25470  EZYV25471  North America              Master's                  Y
# 25473  EZYV25474           Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %% [markdown]
# **Emperical rule**

# %% [markdown]
# - 68% of data available between u-1*sd to u+1*sd
# - mean
# - sd
# - 1b=mean-1*sd
# - ub=mean+1*sd

# %%
mean=wage_data.mean()
mean
# Out:
# np.float64(74455.81459209183)

# %%
sd=wage_data.std()
sd
# Out:
# 52815.94232687357

# %%
lb=mean-1*sd
lb
# Out:
# np.float64(21639.872265218262)

# %%
ub=mean+1*sd
ub
# Out:
# np.float64(127271.7569189654)

# %%
con1=wage_data>lb
con1
# Out:
# 0        False
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 25475     True
# 25476     True
# 25477     True
# 25478     True
# 25479     True
# Name: prevailing_wage, Length: 25480, dtype: bool

# %%
con2=wage_data<ub
con2
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4        False
#          ...
# 25475     True
# 25476    False
# 25477    False
# 25478     True
# 25479     True
# Name: prevailing_wage, Length: 25480, dtype: bool

# %%
con=con1 & con2
con
# Out:
# 0        False
# 1         True
# 2         True
# 3         True
# 4        False
#          ...
# 25475     True
# 25476    False
# 25477    False
# 25478     True
# 25479     True
# Name: prevailing_wage, Length: 25480, dtype: bool

# %%
np.sum(con)
# Out:
# np.int64(17171)

# %%
np.sum(con)==68%(25480)/100
# Out:
# np.False_

# %%
np.sum(con)==95.7%(25480)/100
# Out:
# np.False_

# %%
np.sum(con)==99.9%(25480)/100
# Out:
# np.False_

# %% [markdown]
# **conclusion is wage_data does not follow normal distribution**

# %%
wage_data=visa_df['prevailing_wage']
plt.hist(wage_data)
# Out:
# (array([6038., 5504., 5681., 4551., 2334.,  624.,  373.,  240.,  114.,
#           21.]),
#  array([2.13670000e+00, 3.19229500e+04, 6.38437634e+04, 9.57645767e+04,
#         1.27685390e+05, 1.59606203e+05, 1.91527017e+05, 2.23447830e+05,
#         2.55368643e+05, 2.87289457e+05, 3.19210270e+05]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# **Box plot**

# %%
wage_data=visa_df['prevailing_wage']
plt.boxplot(wage_data,vert=False)
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 wage_data=visa_df['prevailing_wage']
# ----> 2 plt.boxplot()
#       3 plt.show()
#
# File ~\anaconda3\Lib\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\matplotlib\_api\deprecation.py:295, in rename_parameter.<locals>.wrapper(*args, **kwargs)
#     290     warn_deprecated(
# ...

# %%
wage = visa_df['prevailing_wage']

Q1 = wage.quantile(0.25)
Q3 = wage.quantile(0.75)

IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

outliers = wage[(wage < lower) | (wage > upper)]

print(outliers)
# Out:
# 14       220081.73
# 34       225569.73
# 130      247393.01
# 216      269321.68
# 221      219529.62
#            ...
# 25191    280482.51
# 25195    234308.77
# 25468    272715.74
# 25469    273772.47
# 25476    279174.79
# Name: prevailing_wage, Length: 427, dtype: float64

# %%
Q1=wage_data.quantile(0.25)
Q1
# Out:
# np.float64(34015.479999999996)

# %%
Q2=wage_data.quantile(0.50)
Q2
# Out:
# np.float64(70308.20999999999)

# %%
Q3=wage_data.quantile(0.75)
Q3
# Out:
# np.float64(107735.51250000001)

# %%
IQR=Q3-Q1
IQR
# Out:
# np.float64(73720.03250000002)

# %%
lb=Q1-1.5*IQR
lb
# Out:
# np.float64(-76564.56875000002)

# %%
ub=Q3+1.5*IQR
ub
# Out:
# np.float64(218315.56125000003)

# %%
con1=wage_data<lb
con1
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 25475    False
# 25476    False
# 25477    False
# 25478    False
# 25479    False
# Name: prevailing_wage, Length: 25480, dtype: bool

# %%
con2=wage_data>ub
con2
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 25475    False
# 25476     True
# 25477    False
# 25478    False
# 25479    False
# Name: prevailing_wage, Length: 25480, dtype: bool

# %%
con=con1|con2
con
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 25475    False
# 25476     True
# 25477    False
# 25478    False
# 25479    False
# Name: prevailing_wage, Length: 25480, dtype: bool

# %%
np.sum(con)
# Out:
# np.int64(427)

# %%
# wage_data=visa_df['prevailing_wage']
# Q1=wage_data.quantile(0.25)
# Q3=wage_data.quantile(0.75)
# IQR=Q3-Q1
# lb=Q1-1.5*IQR
# ub=Q3+1.5*IQR
# outlier=wage_data<lb|wage_data>ub
wage_data=visa_df['prevailing_wage']
q1=np.percentile(wage_data,25)
q2=np.percentile(wage_data,50)
q3=np.percentile(wage_data,75)
IQR=q3-q1
lb=q1-1.5*IQR
ub=q3+1.5*IQR
con1=wage_data<lb
con2=wage_data>ub
con=con1|con2
wage_data[con]
np.sum(con)
# Out:
# np.int64(427)

# %%
np.mean(con)
# Out:
# np.float64(0.016758241758241758)

# %%
wage_data[con]
# Out:
# 14       220081.73
# 34       225569.73
# 130      247393.01
# 216      269321.68
# 221      219529.62
#            ...
# 25191    280482.51
# 25195    234308.77
# 25468    272715.74
# 25469    273772.47
# 25476    279174.79
# Name: prevailing_wage, Length: 427, dtype: float64

# %%
wage_outliers=wage_data[con].values
wage_outliers
# Out:
# array([220081.73, 225569.73, 247393.01, 269321.68, 219529.62, 232227.33,
#        238691.32, 220448.17, 230750.48, 235339.91, 232680.65, 256261.78,
#        262189.  , 250510.67, 218554.78, 256205.38, 221944.22, 229950.7 ,
#        222628.84, 229819.69, 233641.72, 274019.43, 218982.83, 230984.28,
#        223128.23, 246705.  , 240266.34, 226090.72, 231949.27, 254604.08,
#        288318.91, 244457.48, 242146.48, 247545.23, 234139.17, 231834.72,
#        222730.57, 239773.63, 220553.95, 237539.32, 266440.49, 277281.01,
#        275627.59, 249291.12, 292106.59, 234012.11, 247009.24, 267726.09,
#        222098.09, 280661.13, 277984.52, 262852.71, 263877.21, 230916.64,
#        264760.64, 267868.56, 222221.67, 242406.32, 276894.08, 281832.93,
#        221033.57, 258292.84, 223492.85, 245418.67, 250289.08, 271344.69,
#        252825.11, 230843.7 , 253668.86, 245819.17, 239465.3 , 236316.36,
#        225268.13, 228941.33, 306021.96, 228074.25, 270799.93, 221982.69,
# ...

# %% [markdown]
# **fill the outliers with median**

# %%
l=[]

for i in wage_data:
    if i in wage_outliers:
        l.append(Q2)
    else:
        l.append(i)
visa_df['wage_Q2']=l

# %% [markdown]
# **np.where**

# %%
wage_data=visa_df['prevailing_wage']
wage_data_q2=visa_df['wage_Q2']
plt.figure(figsize=(10,4))
plt.subplot(1,2,1).boxplot(wage_data,vert=False)
plt.subplot(1,2,2).boxplot(wage_data_q2,vert=False)
plt.show()

# %%
**Capping**
- we can fill the outliers which is less than 25p with 25p values
- we can fill the outliers which is greater than 75p with 75p values

# %%
wage_data=visa_df['prevailing_wage']
q1=np.percentile(wage_data,25)
q2=np.percentile(wage_data,50)
q3=np.percentile(wage_data,75)
IQR=q3-q1
lb=q1-1.5*IQR
ub=q3+1.5*IQR
visa_df['wage_data_cap']=wage_data.clip(lb,ub)

# %%
wage_data=visa_df['wage_data_cap']
wage_data_q2=visa_df['wage_Q2']
wage_data_cap=visa_df['wage_data_cap']
plt.figure(figsize=(14,4))
plt.subplot(1,3,1).boxplot(wage_data,vert=False)
plt.subplot(1,3,2).boxplot(wage_data_q2,vert=False)
plt.subplot(1,3,3).boxplot(wage_data_cap,vert=False)
plt.show()
